# %%
#Mapping libraries
import numpy as np
import pandas as pd
import shapefile as shp
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Import geocoded non-voters & hamilton county shapefile
geocoded = pd.read_csv('../geocoded.csv')
census_blocks_path = ('../cenblk2010.shp')
census_blocks = gpd.read_file(census_blocks_path)

# %%
census_blocks.plot()
